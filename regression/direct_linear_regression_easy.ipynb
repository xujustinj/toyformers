# %% [markdown]
# # Direct Linear Regression (Easy)

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# This task involves a dataset $\left\lbrace (x_1,y_1) \dots, (x_L,y_L) \right\rbrace \subseteq \mathbb{R}^N \times \mathbb{R}$ of varying size $L$, where $y_i = \begin{bmatrix} 1 & x_i^\top \end{bmatrix} \beta$ for some random weights $\beta \in \mathbb{R}^{N+1}$.
#
# The model must use this data to predict the $y$ value corresponding to an unseen point $x$.
#
# The task is evaluated using RMSE of the predictions.

# %%
from torch import Tensor

def get_rmse(
        target: Tensor,
        prediction: Tensor,
) -> float:
    B = target.shape[:-1]
    L = target.shape[-1]
    assert prediction.shape == (*B, L)
    mse = (target - prediction).square().mean(dim=-1)
    return float(mse.sqrt().mean())

# %% [markdown]
# ## Data
#
# During training, the data generation process is as follows:
#
# - sample a length $L$ uniformly from $1$ to $L_\mathrm{max}$ inclusive
# - sample a mean $\mu \in \mathbb{R}^N \sim \mathcal{N}(0,I)$
# - sample $x_1, \dots, x_L \sim \mathcal{N}(\mu,I)$
# - sample weights $\beta \sim \mathcal{N}(0,\mathrm{diag}(1,\tfrac{1}{N},\dots,\tfrac{1}{N}))$
# - for $1 \leq i \leq L$, compute $y_i = f_\theta(x_i)$
#
# For these experiments we use $L_\mathrm{max} = 100$.
#
# During evaluation, we evalute $1000$ times for each value of $L$ from $1$ to $2 L_\mathrm{max}$ and plot the RMSE curve.

# %%
import math

class BatchGroundTruthFunction:
    def __init__(
            self,
            *,
            batch_size: int,
            input_dim: int,
            device: torch.device = device,
    ):
        super().__init__()

        B = batch_size
        I = input_dim

        self.batch_size = B
        self.input_dim = I
        self.weight = torch.randn((B, I), device=device) / math.sqrt(I)
        self.bias = torch.randn((B, 1), device=device)

    def __call__(self, x: Tensor) -> Tensor:
        B, L, I = x.shape
        assert B == self.batch_size
        assert I == self.input_dim

        y = torch.bmm(x, self.weight.unsqueeze(dim=-1))
        assert y.shape == (B, L, 1)
        y = y.squeeze(dim=-1) + self.bias
        assert y.shape == (B, L)

        return y


def get_uniform_batch(
        *,
        length: int,
        input_dim: int,
        batch_size: int,
        next_count: int,
        rng: torch.Generator,
        device: torch.device = device,
) -> tuple[Tensor, Tensor, Tensor, Tensor]:
    B = batch_size
    L = length
    N = input_dim
    C = next_count

    f = BatchGroundTruthFunction(
        batch_size=B,
        input_dim=N,
        device=device,
    )

    mean = torch.randn((B, N), generator=rng, device=device)
    x = torch.randn((B, L+C, N), generator=rng, device=device)
    x = x + mean.unsqueeze(dim=-2)

    y = f(x)
    return x[:,:-C,:], y[:,:-C], x[:,-C:,:], y[:,-C:]


L_max = 100

def get_mixed_batch(
        *,
        input_dim: int,
        batch_size: int,
        next_count: int,
        max_length: int = L_max,
        rng: torch.Generator,
        device: torch.device = device,
) -> tuple[Tensor, Tensor, Tensor, Tensor, Tensor]:
    B = batch_size
    I = input_dim
    C = next_count

    length = torch.randint(
        low=1,
        high=max_length + 1,
        size=(B,),
        generator=rng,
        device=device,
    )
    L = int(length.max())

    x, y, next_x, next_y = get_uniform_batch(
        length=L,
        input_dim=I,
        batch_size=B,
        next_count=C,
        rng=rng,
        device=device,
    )
    mask = torch.arange(L, device=device).unsqueeze(dim=0) < length.unsqueeze(dim=-1)
    return x, y, next_x, next_y, mask

# %% [markdown]
# ## Model

# %%
from typing import Optional

import torch
from torch import nn, Tensor


class DirectRegressionModel(nn.Module):
    def __init__(
            self,
            input_dim: int,
            embed_dim: int,
            num_heads: int,
            num_layers: int,
            normalize_x: bool = True,
            normalize_y: bool = True,
    ):
        super().__init__()

        self.input_dim = input_dim
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        self.num_layers = num_layers
        self.normalize_x = normalize_x
        self.normalize_y = normalize_y

        self.x_ff = nn.Sequential(
            nn.Linear(in_features=input_dim, out_features=embed_dim),
            nn.GELU(),
            nn.Linear(in_features=embed_dim, out_features=embed_dim),
            nn.GELU(),
        )
        self.y_ff = nn.Sequential(
            nn.Linear(in_features=1, out_features=embed_dim),
            nn.GELU(),
            nn.Linear(in_features=embed_dim, out_features=embed_dim),
            nn.GELU(),
        )
        if num_layers > 0:
            layer = nn.TransformerEncoderLayer(
                d_model=embed_dim,
                nhead=num_heads,
                activation="gelu",
                dropout=0.0,
                dim_feedforward=(embed_dim*4),
                norm_first=True,
                batch_first=True,
            )
            self.transformer = nn.TransformerEncoder(layer, num_layers=num_layers)
        self.output_ff = nn.Linear(in_features=embed_dim, out_features=1)

    def forward(
            self,
            *,
            x: Tensor,
            y: Tensor,
            next_x: Tensor,
            next_y: Optional[Tensor] = None,
            mask: Optional[Tensor] = None,
    ) -> tuple[Tensor, Tensor]:
        B, L, I = x.shape
        assert I == self.input_dim
        assert y.shape == (B, L)
        assert next_x.shape == (B, I)
        if next_y is not None:
            assert next_y.shape == (B,)

        if mask is None:
            count = torch.full((B,), fill_value=float(L), device=x.device)
        else:
            count = mask.float().sum(dim=-1).clamp_min(1.0)
            x = torch.where(mask.unsqueeze(dim=-1), x, 0.0)
            y = torch.where(mask, y, 0.0)
            
        if self.normalize_x:
            x_mean = x.sum(dim=-2) / count.unsqueeze(dim=-1)
            x_dev = x - x_mean.unsqueeze(dim=-2)
            if mask is not None:
                x_dev = torch.where(mask, x_dev, 0.0)
            x_std = (x_dev.square().sum(dim=-2) / count.unsqueeze(dim=-1)).sqrt()
            assert x_mean.shape == x_std.shape == (B, I)
            x_std = torch.where(x_std > 0.0, x_std, 1.0)
            x = x_dev / x_std.unsqueeze(dim=-2)
            assert x.shape == (B, L, I)
            next_x = (next_x - x_mean) / x_std
            assert next_x.shape == (B, I)
            
        if self.normalize_y:
            y_mean = y.sum(dim=-1) / count
            y_dev = y - y_mean.unsqueeze(dim=-1)
            if mask is not None:
                y_dev = torch.where(mask, y_dev, 0.0)
            y_std = (y_dev.square().sum(dim=-1) / count).sqrt()
            assert y_mean.shape == y_std.shape == (B,)
            y_std = torch.where(y_std > 0.0, y_std, 1.0)
            y = y_dev / y_std.unsqueeze(dim=-1)
            assert y.shape == (B, L)

        E = self.embed_dim

        x_embeds = self.x_ff(torch.cat((x, next_x.unsqueeze(dim=-2)), dim=-2))
        assert isinstance(x_embeds, Tensor)
        assert x_embeds.shape == (B, L+1, E)

        y_embeds = self.y_ff(y.unsqueeze(dim=-1))
        assert isinstance(y_embeds, Tensor)
        assert y_embeds.shape == (B, L, E)
        y_embeds = torch.cat((y_embeds, torch.zeros((B, 1, E), device=x.device)), dim=-2)
        assert y_embeds.shape == (B, L+1, E)

        embeds = x_embeds + y_embeds

        if self.num_layers > 0:
            if mask is None:
                transformer_mask = None
            else:
                assert mask.shape == (B, L)
                transformer_mask = torch.cat((
                    ~mask,
                    torch.zeros((B, 1), dtype=torch.bool, device=mask.device)
                ), dim=-1)
                assert transformer_mask.shape == (B, L+1)
            embeds = self.transformer(embeds, src_key_padding_mask=transformer_mask)
            assert isinstance(embeds, Tensor)
            assert embeds.shape == (B, L+1, E)

        y_hat = self.output_ff(embeds[:,-1,:])
        assert isinstance(y_hat, Tensor)
        assert y_hat.shape == (B, 1)
        y_hat = y_hat.squeeze(dim=-1)
        if self.normalize_y:
            y_hat = y_hat * y_std + y_mean # type: ignore
        assert y_hat.shape == (B,)

        if next_y is None:
            loss = torch.zeros((), device=x.device)
        else:
            assert y_hat.shape == (B,)
            error = next_y - y_hat
            loss = error.square().mean()

        return y_hat, loss

# %% [markdown]
# ## Experiment

# %%
from IPython.display import clear_output
from matplotlib import pyplot as plt

lengths = list(range(1, 2*L_max+1))

train_steps_per_epoch = 1000
train_batch_size = 1000
eval_next_count = 10
eval_batch_size = 100
epochs_without_improvement_to_stop = 10

def experiment(
    *,
    input_dim: int,
    embed_dim: int,
    num_heads: int,
    num_layers: int,
    seed: int = 0,
) -> float:
    eval_rng = torch.Generator(device=device).manual_seed(0)
    baseline_rmse_acc: list[float] = []
    for L in lengths:
        x, y, next_x, next_y = get_uniform_batch(
            length=L,
            input_dim=input_dim,
            batch_size=eval_batch_size,
            next_count=eval_next_count,
            rng=eval_rng,
        )
        prediction = y.mean(dim=-1, keepdim=True).expand(-1, eval_next_count)
        target = next_y
        rmse = get_rmse(
            target=target,
            prediction=prediction,
        )
        baseline_rmse_acc.append(rmse)
    
    torch.manual_seed(seed)

    model = DirectRegressionModel(
        input_dim=input_dim,
        embed_dim=embed_dim,
        num_heads=num_heads,
        num_layers=num_layers,
        normalize_x=False,
    ).to(device)
    optimizer = torch.optim.AdamW(model.parameters())

    mean_loss_acc: list[float] = []
    rmse_accs: list[list[float]] = []
    mean_rmse_acc: list[float] = []
    best_epoch: int = 0
    best_mean_rmse: float = float("inf")

    train_rng = torch.Generator(device=device).manual_seed(seed)

    epoch = 1
    while True:
        if epoch - best_epoch > epochs_without_improvement_to_stop:
            break

        total_loss = 0.0
        model.train()
        for i in range(train_steps_per_epoch):
            x, y, next_x, next_y, mask = get_mixed_batch(
                input_dim=input_dim,
                batch_size=train_batch_size,
                next_count=1,
                rng=train_rng,
            )
            _, loss = model(
                x=x,
                y=y,
                next_x=next_x.squeeze(dim=-2),
                next_y=next_y.squeeze(dim=-1),
                mask=mask,
            )
            assert isinstance(loss, Tensor)

            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

            total_loss += float(loss)
        mean_loss = total_loss / train_steps_per_epoch
        mean_loss_acc.append(mean_loss)

        eval_rng = torch.Generator(device=device).manual_seed(0)
        with torch.no_grad():
            rmse_acc: list[float] = []
            model.eval()
            for L in lengths:
                x, y, next_x, next_y = get_uniform_batch(
                    length=L,
                    input_dim=input_dim,
                    batch_size=eval_batch_size,
                    next_count=eval_next_count,
                    rng=eval_rng,
                )
                predictions_acc: list[Tensor] = []
                for i in range(eval_next_count):
                    y_hat, _ = model(
                        x=x,
                        y=y,
                        next_x=next_x[:,i,:],
                    )
                    assert isinstance(y_hat, Tensor)
                    predictions_acc.append(y_hat)
                prediction = torch.stack(predictions_acc, dim=-1)
                target = next_y
                rmse = get_rmse(
                    target=target,
                    prediction=prediction,
                )
                rmse_acc.append(rmse)
            rmse_accs.append(rmse_acc)
            mean_rmse = sum(rmse_acc) / len(rmse_acc)
            mean_rmse_acc.append(mean_rmse)

            if mean_rmse < best_mean_rmse:
                best_mean_rmse = mean_rmse
                best_epoch = epoch

        plt.figure(figsize=(8.0, 6.0))
        e = 1
        plt.plot(lengths, baseline_rmse_acc, label=f"Baseline (Sample Mean)")
        while e <= epoch:
            plt.plot(lengths, rmse_accs[e-1], label=f"Epoch {e}", alpha=e/epoch)
            e *= 2
        plt.plot(lengths, rmse_accs[best_epoch-1], label=f"Best Epoch ({best_epoch})")
        plt.xlabel("sequence length")
        plt.xlim(left=1, right=2*L_max)
        plt.xscale("log")
        plt.ylabel("root mean squared error")
        plt.ylim(bottom=0.0)
        plt.legend()
        clear_output(wait=True)
        plt.show()
        for e, (ml, mr) in enumerate(zip(mean_loss_acc, mean_rmse_acc), start=1):
            print(
                f"Epoch {e:03d}: mean loss = {ml:.3f} | mean RMSE = {mr:.3f}"
                + (" (*)" if best_epoch == e else "")
            )

        epoch += 1

    return best_mean_rmse

# %% [markdown]
# **TODO**: ablations

# %%
experiment(
    input_dim=64,
    embed_dim=96,
    num_heads=4,
    num_layers=4,
)
# Out:
# Epoch 001: mean loss = 1.072 | mean RMSE = 0.962
# Epoch 002: mean loss = 0.967 | mean RMSE = 0.899
# Epoch 003: mean loss = 0.897 | mean RMSE = 0.854
# Epoch 004: mean loss = 0.832 | mean RMSE = 0.794
# Epoch 005: mean loss = 0.770 | mean RMSE = 0.744
# Epoch 006: mean loss = 0.732 | mean RMSE = 0.724
# Epoch 007: mean loss = 0.708 | mean RMSE = 0.709
# Epoch 008: mean loss = 0.696 | mean RMSE = 0.697
# Epoch 009: mean loss = 0.687 | mean RMSE = 0.682
# Epoch 010: mean loss = 0.723 | mean RMSE = 0.785
# Epoch 011: mean loss = 0.703 | mean RMSE = 0.687
# Epoch 012: mean loss = 0.672 | mean RMSE = 0.673
# Epoch 013: mean loss = 0.667 | mean RMSE = 0.669
# Epoch 014: mean loss = 0.663 | mean RMSE = 0.674
# Epoch 015: mean loss = 0.662 | mean RMSE = 0.667
# Epoch 016: mean loss = 0.658 | mean RMSE = 0.658
# Epoch 017: mean loss = 0.650 | mean RMSE = 0.657
# Epoch 018: mean loss = 0.648 | mean RMSE = 0.654
# Epoch 019: mean loss = 0.647 | mean RMSE = 0.654
# Epoch 020: mean loss = 0.645 | mean RMSE = 0.652
# Epoch 021: mean loss = 0.645 | mean RMSE = 0.662
# Epoch 022: mean loss = 0.950 | mean RMSE = 0.764
# Epoch 023: mean loss = 0.748 | mean RMSE = 0.711
# Epoch 024: mean loss = 0.662 | mean RMSE = 0.657
# Epoch 025: mean loss = 0.647 | mean RMSE = 0.652
# Epoch 026: mean loss = 0.643 | mean RMSE = 0.640
# Epoch 027: mean loss = 0.635 | mean RMSE = 0.640
# Epoch 028: mean loss = 0.632 | mean RMSE = 0.636 (*)
